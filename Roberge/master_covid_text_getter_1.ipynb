# %% [markdown]
# # Master Text Dataframe Creator:
# <p style="font-size:18px;">Creates a data a four columns:
# <ul  style="font-size:15px;">
# <li>Column One: paper id </li>
# <li>Column Two: The title of the paper</li>
# <li>Column Three: The abstarct if the paper</li>
# <li>Column Four: THe main text of the Paper</li>
# </ul> </p>

# %%
#### dependencies ####
import pandas as pd
import numpy as np
import os
import json
import datetime

#### Navigate to the your corvid 19 download file #####
# %cd "C:\Users\jwr17\Desktop\CORD-19-research-challenge"
# Out:
# C:\Users\jwr17\Desktop\CORD-19-research-challenge

# %%
#### understanding the file system ######
file_paths = ["biorxiv_medrxiv\\biorxiv_medrxiv", "comm_use_subset\\comm_use_subset", "custom_license\\custom_license", "noncomm_use_subset\\noncomm_use_subset"]
i=0
for path in file_paths:
    print(f"file folder {path} has a total of {str(len(os.listdir(path)))} files")
    i = i + len(os.listdir(path))
print(f"\n total files are equal to {str(i)}")
# Out:
# file folder biorxiv_medrxiv\biorxiv_medrxiv has a total of 885 files
# file folder comm_use_subset\comm_use_subset has a total of 9118 files
# file folder custom_license\custom_license has a total of 16959 files
# file folder noncomm_use_subset\noncomm_use_subset has a total of 2353 files
#
#  total files are equal to 29315

# %% [markdown]
# # biorxiv_medrxiv, commercial use, and none comercial use

# %%
########################################################### reading in the file Loop #################################################################################
master_text=[]
i=0
count = 0
file_paths = ["biorxiv_medrxiv\\biorxiv_medrxiv", "comm_use_subset\\comm_use_subset", "custom_license\\custom_license", "noncomm_use_subset\\noncomm_use_subset"]


for path in file_paths: 
    for  file in os.listdir(path): ### cycles through every json file from a given file path
        try:
            with open(path + "\\" +file, "r") as read_file: ### reading in json file
                data = json.load(read_file)
            read_file.close()

            paper_id = data['paper_id']
            papepr_title = data['metadata']['title']
            
            ##### geting abstract #######
            abs_text = ""
            for main in data['abstract']:
                abs_text = abs_text + ' '+ main['text']
            abs_text

            ####  getting body text ####
            main_text = ""
            for main in data['body_text']:
                main_text = main_text + ' '+ main['text']
            
            ### adding to list ###
            master_text.append({'paper_id': paper_id,'papepr_title': papepr_title, 'abstract': abs_text, 'main_text': main_text, "file_path": re.findall(r".+\\", path)[0][:-2]})
        except:
            i+=1
            print(f"total skiped: {str(i)}")
        count+=1
        if count%500 == 0: f"complted {str(count)} text files as of {str(datetime.datetime.now())}"

        

master_text = pd.DataFrame(master_text)
master_text
# Out:
#                                        paper_id  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      0139ea4ca580af99b602c6435368e7fdbefacb03
# 4      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# ...                                         ...
# 29310  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 29311  ff6d57f2aad99be129432058665b361dc18747e8
# 29312  ff83907653a4c4500e8c509ca28169e924742b40
# 29313  ffe718db1820f27bf274e3fc519ab78e450de288
# 29314  ffed5d2a31a0c1a0db11905fe378e7735b6d70ca
#
#                                             papepr_title  \
# 0      The RNA pseudoknots in foot-and-mouth disease ...
# 1      Healthcare-resource-adjusted vulnerabilities t...
# 2      Real-time, MinION-based, amplicon sequencing f...
# 3      A Combined Evidence Approach to Prioritize Nip...
# 4      Assessing spread risk of Wuhan novel coronavir...
# ...                                                  ...
# 29310          Understanding Human Coronavirus HCoV-NL63
# 29311  Brief Definitive Report MACROPHAGES GENETICALL...
# 29312  Identification of a Subdomain of CENPB That Is...
# 29313  Replication enhancer elements within the open ...
# 29314  Supplemental material for the paper "Evidence ...
#
#                                                 abstract  \
# 0       word count: 194 22 Text word count: 5168 23 2...
# 1
# 2       Infectious bronchitis (IB) causes significant...
# 3       Nipah Virus (NiV) came into limelight recentl...
# 4       Background: A novel coronavirus (2019-nCoV) e...
# ...                                                  ...
# 29310   Even though coronavirus infection of humans i...
# 29311   There is extensive evidence that cultured mac...
# 29312   We have combined in vivo and in vitro approac...
# 29313   We provide experimental evidence of a replica...
# 29314   Israel. *Corresponding author (TT): tamirtul@...
#
#                                                main_text          file_path
# 0       VP3, and VP0 (which is further processed to V...     biorxiv_medrxi
# 1       The 2019-nCoV epidemic has spread across Chin...     biorxiv_medrxi
# 2       Infectious bronchitis (IB), which is caused b...     biorxiv_medrxi
# 3       Nipah is an infectious negative-sense single-...     biorxiv_medrxi
# 4       In December 2019, a cluster of patients with ...     biorxiv_medrxi
# ...                                                  ...                ...
# 29310   Regardless of geographic location, respirator...  noncomm_use_subse
# 29311   Experiments were designed to test whether sub...  noncomm_use_subse
# 29312   can function in an autonomous fashion, reloca...  noncomm_use_subse
# 29313   Tick-borne encephalitis virus (TBEV) is a hum...  noncomm_use_subse
# 29314   20min). We trimmed the poly-A adaptors from t...  noncomm_use_subse
#
# [29315 rows x 5 columns]

# %%
# %cd "C:\Users\jwr17\Desktop\CORD-19-research-challenge\my_code_dfs"
master_text.to_csv("master_text.csv")

# %% [markdown]
# # EDA Analysis:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %cd "C:\Users\jwr17\Desktop\CORD-19-research-challenge\my_code_dfs"
master_test = pd.read_csv('master_text.csv')
meta = pd.read_csv("C:\\Users\\jwr17\\Desktop\\CORD-19-research-challenge\\metadata.csv")
# Out:
# C:\Users\jwr17\Anaconda3\envs\tensor 2\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\jwr17\Anaconda3\envs\tensor 2\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\jwr17\Anaconda3\envs\tensor 2\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\jwr17\Anaconda3\envs\tensor 2\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\jwr17\Anaconda3\envs\tensor 2\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\jwr17\Desktop\CORD-19-research-challenge\my_code_dfs

# %%
### papers that are not in json froma
meta[~meta.sha.isin(master_test.paper_id)]
# Out:
#                                                      sha  source_x  \
# 0                                                    NaN  Elsevier
# 1                                                    NaN  Elsevier
# 2                                                    NaN  Elsevier
# 4                                                    NaN  Elsevier
# 13                                                   NaN  Elsevier
# ...                                                  ...       ...
# 44207  e44632c9b598cac15ccda521e13c65ca9fcf7426; 6695...       PMC
# 44210  a396657b0c580d496e109b82967c1a89d191ee9b; 560c...       PMC
# 44211  7d77a852039f1cfc2c13843ecfa721c1fe49528c; fc02...       PMC
# 44212                                                NaN  Elsevier
# 44213  428d1091cf63872ea81cb3c1632d76c4813748a1; 8244...       PMC
#
#                                                    title  \
# 0      Intrauterine virus infections and congenital h...
# 1                      Coronaviruses in Balkan nephritis
# 2      Cigarette smoking and coronary heart disease: ...
# 4      Epidemiology of community-acquired respiratory...
# 13     Monoclonal antibodies identify multiple epitop...
# ...                                                  ...
# 44207  The Healthy Infant Nasal Transcriptome: A Benc...
# 44210  The intrinsic vulnerability of networks to epi...
# 44211  Lung ultrasound as a diagnostic tool for radio...
# 44212                           Calculating virus spread
# 44213  Viral etiology of hospitalized acute lower res...
#
#                                    doi       pmcid   pubmed_id      license  \
# 0         10.1016/0002-8703(72)90077-4         NaN   4361535.0    els-covid
# 1         10.1016/0002-8703(80)90355-5         NaN   6243850.0    els-covid
# 2         10.1016/0002-8703(80)90356-7         NaN   7355701.0    els-covid
# 4         10.1016/0002-9343(85)90361-4         NaN   4014285.0    els-covid
# 13        10.1016/0006-291X(85)91946-1         NaN   2409966.0    els-covid
# ...                                ...         ...         ...          ...
# 44207                10.1038/srep33994  PMC5034274  27658638.0        cc-by
# 44210  10.1016/j.ecolmodel.2018.05.013  PMC6039859  30210182.0  cc-by-nc-nd
# 44211       10.1016/j.rmed.2017.05.007  PMC5480773  28610670.0        cc-by
# 44212    10.1016/S0262-4079(20)30402-4         NaN         NaN    els-covid
# 44213          10.3325/cmj.2013.54.122  PMC3641872  23630140.0        cc-by
#
#                                                 abstract publish_time  \
# 0      Abstract The etiologic basis for the vast majo...   1972-12-31
# 1                                                    NaN   1980-03-31
# 2                                                    NaN   1980-03-31
# 4      Abstract Upper respiratory tract infections ar...   1985-06-28
# 13     Abstract Nine hybridoma cell lines secreting a...   1985-06-28
# ...                                                  ...          ...
# 44207  Responses by resident cells are likely to play...  2016 Sep 23
# 44210  Contact networks are convenient models to inve...  2018 Sep 10
# 44211  BACKGROUND: Pneumonia is a leading cause of mo...     2017 Jul
# 44212  Getting a full picture of the coronavirus outb...   2020-02-22
# 44213  AIM: To estimate the proportional contribution...     2013 Apr
#
#                                                  authors  \
# 0                                      Overall, James C.
# 1      Georgescu, Leonida; Diosi, Peter; Buţiu, Ioan;...
# 2                                       Friedman, Gary D
# 4                                  Garibaldi, Richard A.
# 13     Cherel, Isabelle; Grosclaude, Jeanne; Rouze, P...
# ...                                                  ...
# 44207  Chu, Chin-Yi; Qiu, Xing; Wang, Lu; Bhattachary...
# 44210  Strona, G.; Carstens, C.J.; Beck, P.S.A.; Han,...
# 44211  Ellington, Laura E.; Gilman, Robert H.; Chavez...
# 44212                                    Kucharski, Adam
# 44213  Lukšić, Ivana; Kearns, Patrick K; Scott, Fiona...
#
#                                                  journal  \
# 0                                 American Heart Journal
# 1                                 American Heart Journal
# 2                                 American Heart Journal
# 4                       The American Journal of Medicine
# 13     Biochemical and Biophysical Research Communica...
# ...                                                  ...
# 44207                                            Sci Rep
# 44210                                        Ecol Modell
# 44211                                         Respir Med
# 44212                                      New Scientist
# 44213                                        Croat Med J
#
#        Microsoft Academic Paper ID WHO #Covidence  has_full_text  \
# 0                              NaN            NaN          False
# 1                              NaN            NaN          False
# 2                              NaN            NaN          False
# 4                              NaN            NaN          False
# 13                             NaN            NaN          False
# ...                            ...            ...            ...
# 44207                          NaN            NaN           True
# 44210                          NaN            NaN           True
# 44211                          NaN            NaN           True
# 44212                 3.006474e+09          #1600          False
# 44213                          NaN            NaN           True
#
#            full_text_file
# 0          custom_license
# 1          custom_license
# 2          custom_license
# 4          custom_license
# 13         custom_license
# ...                   ...
# 44207     comm_use_subset
# 44210  noncomm_use_subset
# 44211     comm_use_subset
# 44212      custom_license
# 44213     comm_use_subset
#
# [16530 rows x 15 columns]

# %%
# Out:
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3        aecbc613ebdab36753235197ffb4f35734b5ca63
# 4                                             NaN
#                            ...
# 44215    d4f00f66c732c292fcfc28b19f44daa2fa620901
# 44216    ec575d33c0d3b34af7644fcfed64af045a75ab63
# 44217    7f8715a818bfd325bf4413d3c07003d7ce7b6f7e
# 44218    07e78e218a159c35e9599e3751a99551a271597b
# 44219    04bc03c90437934a75fc6fdc228817234ef84c3a
# Name: sha, Length: 44220, dtype: object
