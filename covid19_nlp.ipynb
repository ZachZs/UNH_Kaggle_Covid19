# %%
# %cd "D:\COVID-19"
# Out:
# D:\COVID-19

# %%
import os
files = []
for f in os.listdir():
    files.append(f)
len(files)
# Out:
# 9

# %%
files
# Out:
# ['biorxiv_medrxiv',
#  'comm_use_subset',
#  'CORD-19-research-challenge.zip',
#  'COVID.DATA.LIC.AGMT.pdf',
#  'custom_license',
#  'json_schema.txt',
#  'metadata.csv',
#  'metadata.readme',
#  'noncomm_use_subset']

# %%
import json

# D:\COVID-19\biorxiv_medrxiv\biorxiv_medrxiv
# D:\COVID-19\comm_use_subset\comm_use_subset
# D:\COVID-19\custom_license\custom_license
# D:\COVID-19\noncomm_use_subset\noncomm_use_subset

all_files = []
count = 0
path = ["biorxiv_medrxiv\\biorxiv_medrxiv", 
        "comm_use_subset\\comm_use_subset",
       "custom_license\\custom_license",
       "noncomm_use_subset\\noncomm_use_subset"]

abstract = []
body_text = []
paper_id = []
metadata = []


for i in path:
    for filename in os.listdir(i):
        print(filename)
        all_files.append(filename)
        print(len(all_files))
        count += 1
        with open(i+'\\'+filename) as f:
            fresh_data = json.load(f)
        for key in fresh_data.keys():
            if key == 'body_text':
                body_text.append(fresh_data[key])
            if key == 'paper_id':
                paper_id.append(fresh_data[key])
            if key == 'abstract':
                abstract.append(fresh_data[key])
            if key == 'metadata':
                metadata.append(fresh_data[key])
# Out:
# 0015023cc06b5362d332b3baf348d11567ca2fbb.json
# 1
# 004f0f8bb66cf446678dc13cf2701feec4f36d76.json
# 2
# 00d16927588fb04d4be0e6b269fc02f0d3c2aa7b.json
# 3
# 0139ea4ca580af99b602c6435368e7fdbefacb03.json
# 4
# 013d9d1cba8a54d5d3718c229b812d7cf91b6c89.json
# 5
# 01d162d7fae6aaba8e6e60e563ef4c2fca7b0e18.json
# 6
# 01e3b313e78a352593be2ff64927192af66619b5.json
# 7
# 02201e4601ab0eb70b6c26480cf2bfeae2625193.json
# 8
# 0255ea4b2f26a51a3bfa3bd8f3e1978c82c976d5.json
# 9
# 029c1c588047f1d612a219ee15494d2d19ff7439.json
# 10
# 03ce432f27c7df6af22b92245a614db2ecb5de5f.json
# 11
# 03ea3a614b56409d3f099c9ad764864293132540.json
# 12
# 04030bba3035a58c7725ae267973206f6eb6c0b4.json
# 13
# 041bae0a6de2b69979d39460b3f2ee8946534ec2.json
# 14
# 05082393ba4c7ec530190dd887d99c74fd72f6d6.json
# 15
# 05d47dd5b46f86428de058db4ecc8bca76a9ad16.json
# 16
# 05d99c07db59b6948e39bfa62c2cbbf62944059a.json
# 17
# 0624a12abfe85c8b5070850d912a2db4cd453236.json
# 18
# 06a1002f9fbea7179ac3572843f66b14568af6e4.json
# 19
# ...

# %%
import nltk, re, pprint

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Alternative tokenizer
tokenizer = RegexpTokenizer(r'\w+')

en_stop = stopwords.words('english')

# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()

# Additions to the stop word list
en_stop.extend([".","-","(", ")","/", ",", "’", "”","“", "\n","'d", "'ll", "'re", "'s", "'ve", 'abov', 
                'ani', 'becaus', 'befor', 'could', 'doe', 'dure', 'ha', 'hi', 'might', 'must', "n't", 'need', 
                'onc', 'onli', 'ourselv', 'sha', 'themselv', 'thi', 'veri', 'wa', 'whi', 'wo', 'would', 'yourselv', "!",
               "#", "$","%","'", "+"])

print(en_stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
body_text_text = []
text = []

for i in range(0, len(body_text)):
    print(i)
    #print(len(body_text[i]))
    text = []
    for j in range(0, len(body_text[i])):
        sub_dict = body_text[i][j]
        #print(sub_dict)
        for key, val in sub_dict.items():
            if key == 'text':
                text.append(val)
    print(j)
    body_text_text.append(''.join(map(str, text)))
# Out:
# 0
# 19
# 1
# 6
# 2
# 47
# 3
# 22
# 4
# 46
# 5
# 44
# 6
# 42
# 7
# 102
# 8
# 66
# 9
# 26
# 10
# 48
# 11
# 153
# 12
# 16
# 13
# 38
# 14
# 43
# 15
# 58
# 16
# 30
# 17
# 53
# 18
# 18
# 19
# 38
# 20
# 22
# 21
# 22
# 22
# 51
# 23
# 19
# 24
# 13
# 25
# 39
# 26
# 31
# 27
# 25
# 28
# 58
# 29
# 71
# 30
# 3
# 31
# 30
# 32
# 20
# 33
# 33
# 34
# 12
# 35
# 27
# 36
# 33
# 37
# 35
# 38
# 7
# 39
# 47
# 40
# 25
# 41
# 12
# 42
# 66
# 43
# 43
# 44
# 31
# 45
# 33
# 46
# 28
# 47
# 34
# 48
# 2
# 49
# 19
# 50
# 47
# 51
# 46
# 52
# 43
# 53
# 16
# 54
# 243
# 55
# 33
# 56
# 5
# 57
# 8
# 58
# 39
# 59
# 51
# 60
# 26
# 61
# 26
# 62
# 33
# 63
# 39
# 64
# 66
# 65
# 57
# 66
# 32
# 67
# 26
# 68
# 48
# 69
# 55
# 70
# 33
# 71
# 26
# 72
# 36
# 73
# 35
# 74
# 11
# 75
# 31
# 76
# 11
# 77
# 14
# 78
# 64
# 79
# 29
# 80
# 50
# 81
# 12
# 82
# 38
# 83
# 34
# 84
# 24
# 85
# 29
# 86
# 47
# 87
# 3
# 88
# 66
# 89
# 24
# 90
# 20
# 91
# 20
# 92
# 34
# 93
# 51
# 94
# 36
# 95
# 6
# 96
# 62
# 97
# 36
# 98
# 71
# 99
# 31
# 100
# 1
# ...

# %%
documents = [document.split(" ") for document in body_text_text]

# %%
documents[3]
# Out:
# ['Nipah',
#  'is',
#  'an',
#  'infectious',
#  'negative-sense',
#  'single-stranded',
#  'RNA',
#  'virus',
#  'which',
#  'belongs',
#  'to',
#  'the',
#  'genus',
#  'henipavirus',
#  'and',
#  'family',
#  'Paramyxoviridae',
#  '[1]',
#  '.',
#  'It',
#  'is',
#  'a',
#  'pleomorphic',
#  'enveloped',
#  'virus',
#  'with',
#  'a',
#  'particle',
#  'size',
#  'ranging',
#  'from',
#  '40',
#  'to',
#  '1,900nm',
#  '[2]',
#  '.',
#  'While',
#  'fruit',
#  'bats',
#  'are',
#  'thought',
#  'to',
#  'be',
#  'the',
#  'natural',
#  'reservoirs',
#  'of',
#  'the',
#  'virus,',
#  'they',
#  'are',
#  'also',
#  'able',
#  'to',
#  'spread',
#  'to',
#  'humans',
#  'and',
#  'some',
#  'other',
#  'species',
#  '[3]',
#  '.',
#  'There',
#  'are',
#  'two',
#  'major',
#  'genetic',
#  'lineages',
#  'of',
#  'the',
#  'virus',
#  'which',
#  'are',
#  'known',
#  'to',
#  'infect',
#  'humans',
#  'i.e,',
#  'NIV',
#  'Malaysia',
#  '(NIV',
#  'M',
#  ')',
#  'and',
#  'NIV',
# ...

# %%
from nltk.tokenize import word_tokenize
from nltk import FreqDist

#word_tokenize(body_text_text[1])
stop_words = stopwords.words('english')

stop_words.extend([".","-","(", ")","/", ",", "’", "”","“", "\n","'d", "'ll", "'re", "'s", "'ve", 'abov', 
                'ani', 'becaus', 'befor', 'could', 'doe', 'dure', 'ha', 'hi', 'might', 'must', "n't", 'need', 
                'onc', 'onli', 'ourselv', 'sha', 'themselv', 'thi', 'veri', 'wa', 'whi', 'wo', 'would', 'yourselv', "!",
               "#", "$","%","'", "+"])

#tokens = sum([word_tokenize(document) for document in body_text_text], [])
tokens = sum([word_tokenize(body_text_text[0])], [])

filtered_sentence = [w for w in tokens if not w in stop_words] 
words_frequency = FreqDist(filtered_sentence)    
#print(word_tokens) 
#print(filtered_sentence) 
words_frequency.plot(25, cumulative = False)

# %%
tokens = sum([word_tokenize(body_text_text[1])], [])

filtered_sentence = [w for w in tokens if not w in stop_words] 
words_frequency = FreqDist(filtered_sentence)    
#print(word_tokens) 
#print(filtered_sentence) 
words_frequency.plot(25, cumulative = False)

# %%
word_frequency_all_docs = []
words_in_docs = []

for i in range(0,len(body_text_text)):
    tokens = sum([word_tokenize(body_text_text[i])], [])
    filtered_sentence = [w for w in tokens if not w in stop_words] 
    words_frequency = FreqDist(filtered_sentence)  
    words_in_docs.append(filtered_sentence)
    word_frequency_all_docs.append(words_frequency)

# %%
len(word_frequency_all_docs)
# Out:
# 29315

# %%
words_in_docs[4]
# Out:
# ['In',
#  'December',
#  '2019',
#  'cluster',
#  'patients',
#  'pneumonia',
#  'unknown',
#  'cause',
#  'reported',
#  'city',
#  'Wuhan',
#  'Hubei',
#  'Province',
#  'China',
#  'epidemiologically',
#  'linked',
#  'seafood',
#  'wholesale',
#  'market',
#  '[',
#  '1',
#  '2',
#  ']',
#  'It',
#  'determined',
#  'pathogen',
#  'causing',
#  'viral',
#  'pneumonia',
#  'among',
#  'affected',
#  'individuals',
#  'new',
#  'coronavirus',
#  '2019-nCoV',
#  '[',
#  '1',
#  '3',
#  ']',
#  'The',
#  'pathogen',
#  'exhibits',
#  'high',
#  'human-to-human',
#  'transmissibility',
#  'spread',
#  'rapidly',
#  'within',
#  'beyond',
#  'Wuhan',
#  'city',
#  '[',
#  '4',
#  '5',
#  ']',
#  'On',
#  'January',
#  '30',
#  'th',
#  '2020',
#  'World',
#  'Health',
#  'Organization',
#  'WHO',
#  'declared',
#  '2019-nCoV',
#  'outbreak',
#  'Public',
#  'Health',
#  'Emergency',
#  'International',
#  'Concern',
#  '[',
#  '6',
#  ']',
#  '.Wuhan',
#  'central',
#  'China',
# ...

# %%
word_frequency_all_docs[4].plot(25, cumulative = False)

# %%
#word2Vec


vocabulary = []
for doc in words_in_docs[0:100]:
    for word in doc:
        if word not in vocabulary:
            vocabulary.append(word)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
#word2Vec


vocabulary2 = []
for doc in words_in_docs[100:1000]:
    for word in doc:
        if word not in vocabulary2:
            vocabulary2.append(word)

word2idx2 = {w: idx for (idx, w) in enumerate(vocabulary2)}
idx2word2 = {idx: w for (idx, w) in enumerate(vocabulary2)}

vocabulary_size2 = len(vocabulary2)

# %%
vocabulary_size
# Out:
# 25219

# %%
vocabulary
# Out:
# ['VP3',
#  'VP0',
#  'processed',
#  'VP2',
#  'VP4',
#  'virus',
#  'assembly',
#  '6',
#  'The',
#  'P2',
#  '64',
#  'P3',
#  'regions',
#  'encode',
#  'non-structural',
#  'proteins',
#  '2B',
#  '2C',
#  '3A',
#  '3B',
#  '1-3',
#  'VPg',
#  '3C',
#  'pro',
#  '4',
#  'structural',
#  'protein-coding',
#  'region',
#  'replaced',
#  'reporter',
#  'genes',
#  'allow',
#  'study',
#  'genome',
#  '68',
#  'replication',
#  'without',
#  'requirement',
#  'high',
#  'containment',
#  '9',
#  '10',
#  'figure',
#  '1A',
#  '.The',
#  'FMDV',
#  '5′',
#  'UTR',
#  'largest',
#  'known',
#  'picornavirus',
#  'comprising',
#  'approximately',
#  '1300',
#  '71',
#  'nucleotides',
#  'containing',
#  'several',
#  'highly',
#  'structured',
#  'first',
#  '360',
#  '72',
#  'end',
#  'predicted',
#  'fold',
#  'single',
#  'large',
#  'stem',
#  'loop',
#  'termed',
#  'S-fragment',
#  'followed',
#  'PKs',
#  'originally',
#  '1987',
#  'consist',
#  'two',
#  'four',
#  'tandem',
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vec = TfidfVectorizer(use_idf=True, norm='l2')
#svd = TruncatedSVD(n_components=dim)

transformed_dataset = tfidf_vec.fit_transform(body_text_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6e98d239c59a> in <module>
#       7 transformed_dataset = tfidf_vec.fit_transform(body_text_text)
#       8
# ----> 9 transformed_dataset_df = pd.DataFrame(transformed_dataset.toarray(), columns=tfidf_vec.get_feature_names())
#
# NameError: name 'pd' is not defined

# %%
transformed_dataset.shape
# Out:
# (29315, 850658)

# %%
#LSA

from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=100, n_iter=7, random_state=42)
svd.fit(transformed_dataset)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=7,
#              random_state=42, tol=0.0)

# %%
transformed_dataset_svd= svd.fit(transformed_dataset)

# %%
transformed_dataset_svd.components_
# Out:
# array([[ 1.31549072e-03,  6.07379727e-03,  1.80930146e-04, ...,
#          9.67942254e-08,  1.90193893e-08,  1.58263620e-08],
#        [ 1.99621877e-04,  1.56765666e-03, -1.37301825e-06, ...,
#         -1.34764716e-07,  1.19495327e-08,  1.22036800e-07],
#        [ 3.56178875e-04, -4.86849867e-03, -4.63829850e-04, ...,
#         -1.68617689e-06, -2.58275925e-07,  1.86436904e-08],
#        ...,
#        [-4.67917264e-03,  3.52539559e-03, -5.20160033e-04, ...,
#         -8.75419029e-06,  5.16933971e-06, -1.41518757e-05],
#        [ 1.15416693e-03, -5.43537473e-03, -4.02075844e-04, ...,
#          1.92244979e-06,  4.33242175e-06,  4.23462477e-06],
#        [ 8.27328870e-04, -3.43539526e-03, -4.18848724e-04, ...,
#         -6.12594642e-06,  5.92645421e-06,  4.85448091e-06]])

# %%
#print('LSA output shape:', transformed_dataset_svd.shape)
print(svd.explained_variance_ratio_)
# Out:
# [0.03360881 0.01431829 0.01265531 0.01110945 0.00939454 0.00793644
#  0.00685284 0.00623712 0.00537748 0.00524825 0.00465419 0.00455098
#  0.00395594 0.00364443 0.00345886 0.00335869 0.00325865 0.00292251
#  0.00273668 0.00271959 0.00263414 0.00253415 0.00244204 0.00232821
#  0.00212707 0.00211655 0.00207826 0.00197628 0.00191603 0.00186503
#  0.0018398  0.00180231 0.00176823 0.00175539 0.00171165 0.00168872
#  0.00165261 0.00162365 0.00159744 0.001579   0.00156095 0.00153986
#  0.00148506 0.00146378 0.00142772 0.00140147 0.00137777 0.00136564
#  0.00133315 0.00132173 0.00129969 0.0012858  0.00127043 0.00124397
#  0.00123163 0.00121087 0.0011803  0.00117739 0.00116202 0.0011331
#  0.00110556 0.00109291 0.00108916 0.00108438 0.00107279 0.00106868
#  0.00105638 0.00104626 0.00103604 0.00102535 0.0010184  0.00101583
#  0.00100034 0.00098713 0.00097283 0.00096136 0.00095367 0.00094458
#  0.00093046 0.00092572 0.00092058 0.0009133  0.00090175 0.00088957
# ...

# %%
explained_variance = svd.explained_variance_ratio_.sum()
print("Sum of explained variance ratio: %d%%" % (int(explained_variance * 100)))
# Out:
# Sum of explained variance ratio: 25%

# %%
#LDA

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation


def lda(body_text_text, num_of_topic=100):
    vec = CountVectorizer()
    transformed_x_train = vec.fit_transform(body_text_text)
    feature_names = vec.get_feature_names()
    
    lda = LatentDirichletAllocation(n_components=num_of_topic, max_iter=5, learning_method='online', random_state=0)
    lda.fit(transformed_x_train)
    return lda, vec, feature_names


def display_word_distribution(model, feature_names, n_word):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        words = []
        for i in topic.argsort()[:-n_word - 1:-1]:
            words.append(feature_names[i])
        print(words)

        
lda_model, vec, feature_names = lda(body_text_text)


display_word_distribution(
    model=lda_model, feature_names=feature_names, 
    n_word=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-072936d79d12> in <module>
#      24
#      25
# ---> 26 lda_model, vec, feature_names = lda(body_text_text)
#      27
#      28
#
# <ipython-input-59-072936d79d12> in lda(body_text_text, num_of_topic)
#      11
#      12     lda = LatentDirichletAllocation(n_components=num_of_topic, max_iter=5, learning_method='online', random_state=0)
# ---> 13     lda.fit(transformed_x_train)
#      14     return lda, vec, feature_names
#      15
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\decomposition\_lda.py in fit(self, X, y)
#     562                     for idx_slice in gen_batches(n_samples, batch_size):
#     563                         self._em_step(X[idx_slice, :], total_samples=n_samples,
# --> 564                                       batch_update=False, parallel=parallel)
# ...

# %%
#word2vec 


import gensim 
from gensim.models import Word2Vec 

w2v_model = Word2Vec(body_text_text, min_count=1,size= 50,workers=3, window =2, sg = 1)
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
w2v_model.corpus_count
# Out:
# 29315

# %%
w2v_model.corpus_total_words
# Out:
# 913076373

# %%
w2v_model.similar_by_word()
# Out:
# <bound method Word2Vec.load_word2vec_format of <class 'gensim.models.word2vec.Word2Vec'>>

# %%
w2v_model.similarity('genes', 'china')
# Out:
# C:\Users\veena\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-c47731a9c1ae> in <module>
# ----> 1 w2v_model.similarity('genes', 'china')
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in similarity(self, w1, w2)
#    1450
#    1451         """
# -> 1452         return self.wv.similarity(w1, w2)
#    1453
# ...

# %%
from sklearn.cluster import KMeans

num_clusters = 7

km = KMeans(n_clusters=num_clusters)

# %time km.fit(transformed_dataset)

clusters = km.labels_.tolist()
