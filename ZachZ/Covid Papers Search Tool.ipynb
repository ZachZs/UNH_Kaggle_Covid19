# %% [markdown]
# # Loading In The Data

# %% [markdown]
# Zachary Z.
#
# 30 March 2020

# %%
# dependencies
import pandas as pd
import numpy as np

import json
from dictor import dictor

from datetime import datetime
import os

# %%
# navigate to the folder with the files
# %cd ".\CORD-19-research-challenge"
# Out:
# D:\My Computer\My Documents\UNH MS Analytics\COVID19 Kaggle Comp\CORD-19-research-challenge

# %% [markdown]
# load in the data and create a dataframe

# %%
os.listdir()
# Out:
# ['biorxiv_medrxiv',
#  'comm_use_subset',
#  'COVID.DATA.LIC.AGMT.pdf',
#  'custom_license',
#  'FormattedWithNLP.txt',
#  'json_schema.txt',
#  'metadata.csv',
#  'metadata.readme',
#  'noncomm_use_subset']

# %%
folders = ["biorxiv_medrxiv", 
           "comm_use_subset", 
           "custom_license", 
           "noncomm_use_subset"]

# %%
# create the list that will hold the files (for creating a dataframe)
files_list=[]

# get the start time
start = datetime.now()

# loop through the 4 folders
for i in folders: 
    
    # loop through each file
    for j in os.listdir(i):
        with open(i + "\\" + j, "r") as temp:
            data = json.load(temp)
        temp.close()
        
        ### The following code utilizes the dictor package to navigate the nested lists/dicts ###
        
        # get the paper id
        paper_id = dictor(data, "paper_id")
        
        # get the paper title
        paper_title = dictor(data, "metadata.title")
        
        # get the abstract
        paper_abstract = dictor(data, "abstract.0.text")
        
        # get the body text
        paper_body = dictor(data, "body_text.0.text")
            
        # Appending Main Keys to list
        files_list.append({'paper_id': paper_id,
                           'title': paper_title, 
                           'abstract': paper_abstract, 
                           'body': paper_body})
        
# get the total run time
print("Total Runtime:", datetime.now()-start)
# Out:
# Total Runtime: 0:00:30.501005

# %%
df = pd.DataFrame(files_list)

# %%
df
# Out:
#                                        paper_id  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      0139ea4ca580af99b602c6435368e7fdbefacb03
# 4      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# ...                                         ...
# 29310  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 29311  ff6d57f2aad99be129432058665b361dc18747e8
# 29312  ff83907653a4c4500e8c509ca28169e924742b40
# 29313  ffe718db1820f27bf274e3fc519ab78e450de288
# 29314  ffed5d2a31a0c1a0db11905fe378e7735b6d70ca
#
#                                                    title  \
# 0      The RNA pseudoknots in foot-and-mouth disease ...
# 1      Healthcare-resource-adjusted vulnerabilities t...
# 2      Real-time, MinION-based, amplicon sequencing f...
# 3      A Combined Evidence Approach to Prioritize Nip...
# 4      Assessing spread risk of Wuhan novel coronavir...
# ...                                                  ...
# 29310          Understanding Human Coronavirus HCoV-NL63
# 29311  Brief Definitive Report MACROPHAGES GENETICALL...
# 29312  Identification of a Subdomain of CENPB That Is...
# 29313  Replication enhancer elements within the open ...
# 29314  Supplemental material for the paper "Evidence ...
#
#                                                 abstract  \
# 0      word count: 194 22 Text word count: 5168 23 24...
# 1                                                   None
# 2      Infectious bronchitis (IB) causes significant ...
# 3      Nipah Virus (NiV) came into limelight recently...
# 4      Background: A novel coronavirus (2019-nCoV) em...
# ...                                                  ...
# 29310  Even though coronavirus infection of humans is...
# 29311  There is extensive evidence that cultured macr...
# 29312  We have combined in vivo and in vitro approach...
# 29313  We provide experimental evidence of a replicat...
# 29314  Israel. *Corresponding author (TT): tamirtul@p...
#
#                                                     body
# 0      VP3, and VP0 (which is further processed to VP...
# 1      The 2019-nCoV epidemic has spread across China...
# 2      Infectious bronchitis (IB), which is caused by...
# 3      Nipah is an infectious negative-sense single-s...
# 4      In December 2019, a cluster of patients with p...
# ...                                                  ...
# 29310  Regardless of geographic location, respiratory...
# 29311  Experiments were designed to test whether subs...
# 29312  can function in an autonomous fashion, relocat...
# 29313  Tick-borne encephalitis virus (TBEV) is a huma...
# 29314  20min). We trimmed the poly-A adaptors from th...
#
# [29315 rows x 4 columns]

# %% [markdown]
# Load in the metadata file

# %%
# load in the file
meta = pd.read_csv("metadata.csv")
meta
# Out:
#                                             sha  source_x  \
# 0                                           NaN  Elsevier
# 1                                           NaN  Elsevier
# 2                                           NaN  Elsevier
# 3      aecbc613ebdab36753235197ffb4f35734b5ca63  Elsevier
# 4                                           NaN  Elsevier
# ...                                         ...       ...
# 44215  d4f00f66c732c292fcfc28b19f44daa2fa620901       PMC
# 44216  ec575d33c0d3b34af7644fcfed64af045a75ab63  Elsevier
# 44217  7f8715a818bfd325bf4413d3c07003d7ce7b6f7e       PMC
# 44218  07e78e218a159c35e9599e3751a99551a271597b  Elsevier
# 44219  04bc03c90437934a75fc6fdc228817234ef84c3a       PMC
#
#                                                    title  \
# 0      Intrauterine virus infections and congenital h...
# 1                      Coronaviruses in Balkan nephritis
# 2      Cigarette smoking and coronary heart disease: ...
# 3      Clinical and immunologic studies in identical ...
# 4      Epidemiology of community-acquired respiratory...
# ...                                                  ...
# 44215  Epidemiology and clinical profile of pathogens...
# 44216  Functional Analysis of the Transmembrane Domai...
# 44217  Viral Entry Properties Required for Fitness in...
# 44218  Arenavirus reverse genetics: New approaches fo...
# 44219  A New Immunosuppressive Molecule Emodin Induce...
#
#                                 doi       pmcid   pubmed_id    license  \
# 0      10.1016/0002-8703(72)90077-4         NaN   4361535.0  els-covid
# 1      10.1016/0002-8703(80)90355-5         NaN   6243850.0  els-covid
# 2      10.1016/0002-8703(80)90356-7         NaN   7355701.0  els-covid
# 3      10.1016/0002-9343(73)90176-9         NaN   4579077.0  els-covid
# 4      10.1016/0002-9343(85)90361-4         NaN   4014285.0  els-covid
# ...                             ...         ...         ...        ...
# 44215  10.1371/journal.pone.0188325  PMC5693464  29149199.0      cc-by
# 44216     10.1016/j.jmb.2008.12.029  PMC2750892  19121325.0  els-covid
# 44217         10.1128/mBio.00898-18  PMC6030562  29970463.0      cc-by
# 44218   10.1016/j.virol.2011.01.013  PMC3057228  21324503.0  els-covid
# 44219      10.3389/fimmu.2017.01519  PMC5682309  29167674.0      cc-by
#
#                                                 abstract publish_time  \
# 0      Abstract The etiologic basis for the vast majo...   1972-12-31
# 1                                                    NaN   1980-03-31
# 2                                                    NaN   1980-03-31
# 3      Abstract Middle-aged female identical twins, o...   1973-08-31
# 4      Abstract Upper respiratory tract infections ar...   1985-06-28
# ...                                                  ...          ...
# 44215  This study aimed to identify a broad spectrum ...  2017 Nov 17
# 44216  Abstract To enter cells, enveloped viruses use...   2009-02-13
# 44217  Human parainfluenza viruses cause a large burd...   2018 Jul 3
# 44218  Abstract Several arenaviruses, chiefly Lassa v...   2011-03-15
# 44219  Due to vigorous alloimmunity, an allograft is ...   2017 Nov 8
#
#                                                  authors  \
# 0                                      Overall, James C.
# 1      Georgescu, Leonida; Diosi, Peter; Buţiu, Ioan;...
# 2                                       Friedman, Gary D
# 3      Brunner, Carolyn M.; Horwitz, David A.; Shann,...
# 4                                  Garibaldi, Richard A.
# ...                                                  ...
# 44215  Brini, Ines; Guerrero, Aida; Hannachi, Naila; ...
# 44216  Bissonnette, Mei Lin Z.; Donald, Jason E.; DeG...
# 44217  Iketani, Sho; Shean, Ryan C.; Ferren, Marion; ...
# 44218  Emonet, Sebastien E.; Urata, Shuzo; de la Torr...
# 44219  Qiu, Feifei; Liu, Huazhen; Liang, Chun-Ling; N...
#
#                                 journal  Microsoft Academic Paper ID  \
# 0                American Heart Journal                          NaN
# 1                American Heart Journal                          NaN
# 2                American Heart Journal                          NaN
# 3      The American Journal of Medicine                          NaN
# 4      The American Journal of Medicine                          NaN
# ...                                 ...                          ...
# 44215                          PLoS One                          NaN
# 44216      Journal of Molecular Biology                          NaN
# 44217                              mBio                          NaN
# 44218                          Virology                          NaN
# 44219                     Front Immunol                          NaN
#
#       WHO #Covidence  has_full_text   full_text_file
# 0                NaN          False   custom_license
# 1                NaN          False   custom_license
# 2                NaN          False   custom_license
# 3                NaN           True   custom_license
# 4                NaN          False   custom_license
# ...              ...            ...              ...
# 44215            NaN           True  comm_use_subset
# 44216            NaN           True   custom_license
# 44217            NaN           True  comm_use_subset
# 44218            NaN           True   custom_license
# 44219            NaN           True  comm_use_subset
#
# [44220 rows x 15 columns]

# %%
# check only the ones with actual text
meta_full = meta[meta['has_full_text'] == True]
meta_full
# Out:
#                                             sha  source_x  \
# 3      aecbc613ebdab36753235197ffb4f35734b5ca63  Elsevier
# 5      212e990b378e8d267042753d5f9d4a64ea5e9869  Elsevier
# 6      bf5d344243153d58be692ceb26f52c08e2bd2d2f  Elsevier
# 7      ddd2ecf42ec86ad66072962081e1ce4594431f9c  Elsevier
# 8      a55cb4e724091ced46b5e55b982a14525eea1c7e  Elsevier
# ...                                         ...       ...
# 44215  d4f00f66c732c292fcfc28b19f44daa2fa620901       PMC
# 44216  ec575d33c0d3b34af7644fcfed64af045a75ab63  Elsevier
# 44217  7f8715a818bfd325bf4413d3c07003d7ce7b6f7e       PMC
# 44218  07e78e218a159c35e9599e3751a99551a271597b  Elsevier
# 44219  04bc03c90437934a75fc6fdc228817234ef84c3a       PMC
#
#                                                    title  \
# 3      Clinical and immunologic studies in identical ...
# 5      Infectious diarrhea: Pathogenesis and risk fac...
# 6      New perspectives on the pathogenesis of rheuma...
# 7      Management of acute and chronic respiratory tr...
# 8      Acute bronchitis: Results of U.S. and European...
# ...                                                  ...
# 44215  Epidemiology and clinical profile of pathogens...
# 44216  Functional Analysis of the Transmembrane Domai...
# 44217  Viral Entry Properties Required for Fitness in...
# 44218  Arenavirus reverse genetics: New approaches fo...
# 44219  A New Immunosuppressive Molecule Emodin Induce...
#
#                                 doi       pmcid   pubmed_id    license  \
# 3      10.1016/0002-9343(73)90176-9         NaN   4579077.0  els-covid
# 5      10.1016/0002-9343(85)90367-5         NaN   2861742.0  els-covid
# 6      10.1016/0002-9343(88)90356-7         NaN   3052052.0  els-covid
# 7      10.1016/0002-9343(88)90456-1         NaN   3048091.0  els-covid
# 8      10.1016/0002-9343(92)90608-E         NaN   1621745.0  els-covid
# ...                             ...         ...         ...        ...
# 44215  10.1371/journal.pone.0188325  PMC5693464  29149199.0      cc-by
# 44216     10.1016/j.jmb.2008.12.029  PMC2750892  19121325.0  els-covid
# 44217         10.1128/mBio.00898-18  PMC6030562  29970463.0      cc-by
# 44218   10.1016/j.virol.2011.01.013  PMC3057228  21324503.0  els-covid
# 44219      10.3389/fimmu.2017.01519  PMC5682309  29167674.0      cc-by
#
#                                                 abstract publish_time  \
# 3      Abstract Middle-aged female identical twins, o...   1973-08-31
# 5      Abstract Our understanding of the pathogenesis...   1985-06-28
# 6      Abstract In the pathogenesis of rheumatoid art...   1988-10-14
# 7      Abstract Pharyngitis, bronchitis, and pneumoni...   1988-09-16
# 8      Abstract Acute bronchitis, an illness frequent...   1992-06-22
# ...                                                  ...          ...
# 44215  This study aimed to identify a broad spectrum ...  2017 Nov 17
# 44216  Abstract To enter cells, enveloped viruses use...   2009-02-13
# 44217  Human parainfluenza viruses cause a large burd...   2018 Jul 3
# 44218  Abstract Several arenaviruses, chiefly Lassa v...   2011-03-15
# 44219  Due to vigorous alloimmunity, an allograft is ...   2017 Nov 8
#
#                                                  authors  \
# 3      Brunner, Carolyn M.; Horwitz, David A.; Shann,...
# 5                                       Cantey, J.Robert
# 6                                    Zvaifler, Nathan J.
# 7                                     Ellner, Jerrold J.
# 8                                       Dere, Willard H.
# ...                                                  ...
# 44215  Brini, Ines; Guerrero, Aida; Hannachi, Naila; ...
# 44216  Bissonnette, Mei Lin Z.; Donald, Jason E.; DeG...
# 44217  Iketani, Sho; Shean, Ryan C.; Ferren, Marion; ...
# 44218  Emonet, Sebastien E.; Urata, Shuzo; de la Torr...
# 44219  Qiu, Feifei; Liu, Huazhen; Liang, Chun-Ling; N...
#
#                                 journal  Microsoft Academic Paper ID  \
# 3      The American Journal of Medicine                          NaN
# 5      The American Journal of Medicine                          NaN
# 6      The American Journal of Medicine                          NaN
# 7      The American Journal of Medicine                          NaN
# 8      The American Journal of Medicine                          NaN
# ...                                 ...                          ...
# 44215                          PLoS One                          NaN
# 44216      Journal of Molecular Biology                          NaN
# 44217                              mBio                          NaN
# 44218                          Virology                          NaN
# 44219                     Front Immunol                          NaN
#
#       WHO #Covidence  has_full_text   full_text_file
# 3                NaN           True   custom_license
# 5                NaN           True   custom_license
# 6                NaN           True   custom_license
# 7                NaN           True   custom_license
# 8                NaN           True   custom_license
# ...              ...            ...              ...
# 44215            NaN           True  comm_use_subset
# 44216            NaN           True   custom_license
# 44217            NaN           True  comm_use_subset
# 44218            NaN           True   custom_license
# 44219            NaN           True  comm_use_subset
#
# [28462 rows x 15 columns]

# %%
# merge the metadata with the already created df (containing raw papers)
combo_df = pd.merge(df, meta_full, how='inner', left_on="paper_id", right_on='sha')

# reset the index
combo_df = combo_df.reset_index(drop=True)

# drop duplicate columns
combo_df.drop(columns=['abstract_x', 'title_x', 'source_x'], inplace=True)

# rename the columns
combo_df.rename(columns={"abstract_y":"abstract", "title_y":"title"}, inplace=True)

# replace certain column missing values with blank strings
combo_df['abstract'].fillna('', inplace=True)
combo_df['title'].fillna('', inplace=True)
combo_df['body'].fillna('', inplace=True)

combo_df
# Out:
#                                        paper_id  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      0139ea4ca580af99b602c6435368e7fdbefacb03
# 4      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# ...                                         ...
# 27685  ff3db609dbf2669d8d528279ef32280c2646ba85
# 27686  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 27687  ff6d57f2aad99be129432058665b361dc18747e8
# 27688  ff83907653a4c4500e8c509ca28169e924742b40
# 27689  ffe718db1820f27bf274e3fc519ab78e450de288
#
#                                                     body  \
# 0      VP3, and VP0 (which is further processed to VP...
# 1      The 2019-nCoV epidemic has spread across China...
# 2      Infectious bronchitis (IB), which is caused by...
# 3      Nipah is an infectious negative-sense single-s...
# 4      In December 2019, a cluster of patients with p...
# ...                                                  ...
# 27685  Over the past few decades, the world has witne...
# 27686  Regardless of geographic location, respiratory...
# 27687  Experiments were designed to test whether subs...
# 27688  can function in an autonomous fashion, relocat...
# 27689  Tick-borne encephalitis virus (TBEV) is a huma...
#
#                                             sha  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      0139ea4ca580af99b602c6435368e7fdbefacb03
# 4      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# ...                                         ...
# 27685  ff3db609dbf2669d8d528279ef32280c2646ba85
# 27686  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 27687  ff6d57f2aad99be129432058665b361dc18747e8
# 27688  ff83907653a4c4500e8c509ca28169e924742b40
# 27689  ffe718db1820f27bf274e3fc519ab78e450de288
#
#                                                    title  \
# 0      The RNA pseudoknots in foot-and-mouth disease ...
# 1      Healthcare-resource-adjusted vulnerabilities t...
# 2      Real-time, MinION-based, amplicon sequencing f...
# 3      A Combined Evidence Approach to Prioritize Nip...
# 4      Assessing spread risk of Wuhan novel coronavir...
# ...                                                  ...
# 27685  More than efficacy revealed by single-cell ana...
# 27686          Understanding Human Coronavirus HCoV-NL63
# 27687  Macrophages genetically resistant to mouse hep...
# 27688  Identification of a subdomain of CENP-B that i...
# 27689  Replication enhancer elements within the open ...
#
#                                doi       pmcid   pubmed_id      license  \
# 0        10.1101/2020.01.10.901801         NaN         NaN      biorxiv
# 1      10.1101/2020.02.11.20022111         NaN         NaN      medrvix
# 2                   10.1101/634600         NaN         NaN      biorxiv
# 3        10.1101/2020.03.12.977918         NaN         NaN      biorxiv
# 4      10.1101/2020.02.04.20020479         NaN         NaN      medrvix
# ...                            ...         ...         ...          ...
# 27685       10.1126/sciadv.aax4761  PMC6821460  31692968.0     cc-by-nc
# 27686  10.2174/1874357901004010076  PMC2918871  20700397.0     cc-by-nc
# 27687                          NaN  PMC2190139    175127.0  cc-by-nc-sa
# 27688                          NaN  PMC2289363   1740467.0  cc-by-nc-sa
# 27689           10.1093/nar/gkr237  PMC3303483  21622960.0     cc-by-nc
#
#                                                 abstract publish_time  \
# 0      The positive stranded RNA genomes of picornavi...   2020-01-11
# 1      We integrate the human movement and healthcare...   2020-02-12
# 2      Infectious bronchitis (IB) causes significant ...   2019-05-10
# 3      AbstractBackgroundNipah Virus (NiV) came into ...   2020-03-12
# 4      Background: A novel coronavirus (2019-nCoV) em...   2020-02-05
# ...                                                  ...          ...
# 27685  Because many aspects of viral infection dynami...  2019 Oct 30
# 27686  Even though coronavirus infection of humans is...  2010 May 25
# 27687  Genetic resistance to mouse hepatitis, which r...   1976 Mar 1
# 27688  We have combined in vivo and in vitro approach...   1992 Mar 1
# 27689  We provide experimental evidence of a replicat...  2011 Sep 27
#
#                                                  authors            journal  \
# 0      Ward, J. C. J.; Lasecka-Dykes, L.; Neil, C.; A...                NaN
# 1      Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...                NaN
# 2      Butt, S. L.; Erwood, E. C.; Zhang, J.; Sellers...                NaN
# 3      Nishi Kumari; Ayush Upadhyay; Kishan Kalia; Ra...                NaN
# 4      Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...                NaN
# ...                                                  ...                ...
# 27685  Liu, Wu; Caglar, Mehmet U.; Mao, Zhangming; Wo...            Sci Adv
# 27686           Abdul-Rasool, Sahar; Fielding, Burtram C       Open Virol J
# 27687                                                NaN          J Exp Med
# 27688                                                NaN        J Cell Biol
# 27689  Tuplin, A.; Evans, D. J.; Buckley, A.; Jones, ...  Nucleic Acids Res
#
#        Microsoft Academic Paper ID WHO #Covidence  has_full_text  \
# 0                              NaN            NaN           True
# 1                              NaN            NaN           True
# 2                              NaN            NaN           True
# 3                              NaN            NaN           True
# 4                              NaN            NaN           True
# ...                            ...            ...            ...
# 27685                          NaN            NaN           True
# 27686                          NaN            NaN           True
# 27687                          NaN            NaN           True
# 27688                          NaN            NaN           True
# 27689                          NaN            NaN           True
#
#            full_text_file
# 0         biorxiv_medrxiv
# 1         biorxiv_medrxiv
# 2         biorxiv_medrxiv
# 3         biorxiv_medrxiv
# 4         biorxiv_medrxiv
# ...                   ...
# 27685  noncomm_use_subset
# 27686  noncomm_use_subset
# 27687  noncomm_use_subset
# 27688  noncomm_use_subset
# 27689  noncomm_use_subset
#
# [27690 rows x 16 columns]

# %%
combo_df.iloc[422,]
# Out:
# paper_id                                7b40dfdf9a60cfe4a199cb967ee458b7dfaabe0c
# body                           In December 2019, a cluster of severe pneumoni...
# sha                                     7b40dfdf9a60cfe4a199cb967ee458b7dfaabe0c
# title                          The incubation period of 2019-nCoV from public...
# doi                                                  10.1101/2020.02.02.20020016
# pmcid                                                                        NaN
# pubmed_id                                                                    NaN
# license                                                                  medrvix
# abstract
# publish_time                                                                 NaN
# authors                                                                      NaN
# journal                                                                      NaN
# Microsoft Academic Paper ID                                                  NaN
# WHO #Covidence                                                               NaN
# has_full_text                                                               True
# full_text_file                                                   biorxiv_medrxiv
# Name: 422, dtype: object

# %% [markdown]
# # Create a Search Tool (Basic Version)

# %% [markdown]
# 03 April 2020

# %%
# load the dependencies
import re

import spacy
from spacy.lang.en.stop_words import STOP_WORDS

from tqdm import tqdm_notebook as tqdm

# %%
# load the english language
nlp = spacy.load('en_core_web_md')

# %% [markdown]
# tokenize/format text

# %%
look_at = "body"
combo_df["body_nlp"] = ""

# create tokens for every doc
for i in tqdm(combo_df.index):
    text = combo_df.iloc[i, combo_df.columns.get_loc(look_at)]
    text = text.lower()
    text = nlp(text)
    text2 = [token for token in text if token.is_stop == False]
    text2 = [token for token in text2 if token.is_punct == False]
    text3 = []
    for token in text2:
        text3.append(token.lemma_)
    combo_df.iloc[i, combo_df.columns.get_loc("body_nlp")] = str(text3)

# %%
combo_df

# # save combo_df checkpoint
# combo_df.to_csv("FormattedWithNLP.txt", index=False)

# %% [markdown]
# run a search

# %%
# create a filter to decide which part of the df to look at

while True:
    print("Please enter which area to search")
    print("The options are 'Title', 'Abstract', or 'Body'")
    look_at_input = input()

    # create a list of options
    options_list = ["title", "abstract", "body"]
    
    # lower case the input
    area_tolook = look_at_input.lower()

    # if the string matches the options_list, break the loop, otherwise ask again
    if look_at_input in options_list:
        break
    else:
        print("!")
        print("Invalid area. Please try again.")
        print("-----------------------------------------")

# %%
# generate a search term
search = input("Please input a search term:")

# lower case everything in the search
search = search.lower()

# run the nlp pipeline on it
search = nlp(search)

# remove punctuation and stop words from the search
search2 = [token for token in search if token.is_stop == False]
search2 = [token for token in search2 if token.is_punct == False]

# create a blank list for the lemmanized tokens
search3 = []

# loop through the search term, and add each lemminized token to the new list
for token in search2:
    search3.append(token.lemma_)

# %%
# only use the parts of the df we need (the paper id and the part that is being searched)
temp = combo_df[["paper_id", area_tolook]]

# create a list to hold the paper ids
ids_list = []

# loop through every paper
for i in tqdm(temp.index):
    
    # save the text as a variable and the paper id as a variable
    text = temp.iloc[i, temp.columns.get_loc(area_tolook)]
    paper_id = temp.iloc[i, temp.columns.get_loc("paper_id")]
    
    # loop through all the tokenized search terms
    for j in search3:
        
        ### This chunk is for variations of whitespace in the text ###
        
        # if the variation of the term matches a paper, add the id to a list
        pattern = " " + j + " "
        if pattern in text:
            ids_list.append(paper_id)
            
        # if the variation of the term matches a paper, add the id to a list
        pattern = " " + j
        if pattern in text:
            ids_list.append(paper_id)
            
        # if the variation of the term matches a paper, add the id to a list
        pattern = j + " "
        if pattern in text:
            ids_list.append(paper_id)
            
        ### ------------------------------------------------------ ###

# return the dataframe with only the ids selected
search_df = combo_df[combo_df["paper_id"].isin(ids_list)]
search_df.reset_index(inplace=True, drop=True)

# %%
# print the resulting df

# for i in search_df.index:
#     print(search_df.iloc[i, search_df.columns.get_loc("abstract")])
#     print("########################################################################################################")

search_df

# %% [markdown]
# # Search Tool (Doc2Vec)

# %% [markdown]
# 11 April 2020

# %%
# load the dependencies
import re
import random

import spacy
from spacy.lang.en.stop_words import STOP_WORDS

from gensim.models.doc2vec import Doc2Vec, TaggedDocument

from tqdm import tqdm_notebook as tqdm

from sklearn.cluster import KMeans
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
# load the english language
nlp = spacy.load('en_core_web_md')

# %%
# part to look at
look_at = "abstract"

# %% [markdown]
# tokenize

# %%
doc_list = []

# create tokens for every doc
for i in tqdm(combo_df.index):
    text = combo_df.iloc[i, combo_df.columns.get_loc(look_at)]
    text = text.lower()
    text = nlp(text)
    text2 = [token for token in text if token.is_stop == False]
    text2 = [token for token in text2 if token.is_punct == False]
    text3 = []
    for token in text2:
        text3.append(token.lemma_)
    doc_list.append(text3)
# Out:
# C:\Users\blitz\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=27690.0), HTML(value='')))

# %%
doc_list

# %% [markdown]
# generate the tagged documents for each document

# %%
# initialize a blank list
documents = []

# loop through the list of documents, and create a tagged document of each abstracts tokens with paper_id as the tag
for index, doc in enumerate(doc_list):
    temp = TaggedDocument(doc, [index])
    documents.append(temp)

# %%
documents[4]
# Out:
# TaggedDocument(words=['background', 'novel', 'coronavirus', '2019-ncov', 'emerge', 'wuhan', 'city', 'china', 'end', '2019', 'cause', 'outbreak', 'human', 'human', 'transmission', 'public', 'health', 'emergency', 'international', 'concern', 'declare', 'world', 'health', 'organization', 'january', '30', '2020', 'aim', 'aim', 'estimate', 'potential', 'risk', 'geographic', 'range', 'wuhan', 'novel', 'coronavirus', '2019-ncov', 'spread', 'china', 'january', 'april', '2020', 'method', 'series', 'domestic', 'international', 'travel', 'network', 'base', 'connectivity', 'risk', 'analysis', 'perform', 'de', 'identify', 'aggregated', 'mobile', 'phone', 'datum', 'air', 'passenger', 'itinerary', 'datum', 'case', 'report', 'result', 'cordon', 'sanitaire', 'wuhan', 'likely', 'occur', 'stage', 'peak', 'population', 'number', 'leave', 'city', 'lunar', 'new', 'year', 'lny', 'traveller', 'depart', 'neighbouring', 'city', 'megacitie', 'china', 'estimate', '59,912', 'air', 'passenger', '834', '95', 'ui', '478', '1349', '2019-ncov', 'infection', 'travel', 'wuhan', '382', 'city', 'outside', 'mainland', 'china', 'week', 'prior', 'lockdown', 'wuhan', 'majority', 'city', 'asia', 'major', 'hub', 'europe', 'australia', 'prominent', 'strong', 'correlation', 'see', 'predict', 'importation', 'risk', 'report', 'case', 'significant', 'spread', 'occur', 'large', 'number', 'airline', 'traveller', '3.3', 'million', 'scenario', '75', 'travel', 'reduction', 'normal', 'volume', 'require', 'screen', 'origin', 'high', 'risk', 'city', 'china', 'destination', 'globe', 'following', 'month', 'february', 'april', '2020', 'effectively', 'limit', 'spread', 'current', 'extent', 'conclusion', 'spread', '2019-ncov', 'china', 'international', 'exportation', 'likely', 'occur', 'country', 'especially', 'vulnerable', 'region', 'prepare', 'effort', 'contain', '2019-ncov', 'infection'], tags=[4])

# %% [markdown]
# run the model

# %%
# run the model for doc2vec
model = Doc2Vec(documents, vector_size=50, window=3, min_count=1, workers=4, epochs=1)

# %% [markdown]
# find the most similar papers

# %%
# generate a random doc number to get a paper id
doc_id = random.randint(0, len(documents))
print(doc_id)
print(combo_df.paper_id[doc_id])
del doc_id
# Out:
# 15727
# 63fbcac09bf2a0133b41cb99e93dd2ce3aeeab05

# %%
# create as list of tuples for the n highest similarity locations
while True:
    print("Please Enter the Number of Similar Papers to Find:")
    try:
        # turn the input into an int
        paper_num = int(input())    
        
        # if the number is less than the max number of papers in the df, continue, else as for another number
        if (paper_num > 0) and (paper_num <= (len(combo_df) + 1)):
            break
        else:
            print("That Is Not a Valid Number. Please Try Again\n")
    except:
        print("That Is Not a Valid Number. Please Try Again\n")

loc_list = []

# create a list of tuples of the name and index)
for i in range(0,paper_num):
    name = "Most Similar " + str(i+1)
    tup = (name, i)
    loc_list.append(tup)

# ask for a paper id
while True:
    print("Please Enter a Paper ID:")
    paper_id = input()
    print("\n")
    
    try:
        # assign the index and the title of the paper to variables, if they exist in the df
        doc_index = list(combo_df.paper_id).index(paper_id)
        doc_title = combo_df.title[doc_index]
        break
    except:
        print("That ID is Not Valid. Please Try Again\n")

print("Searching for similar documents to <{}> (ID:{})".format(doc_title, paper_id))
print("-----------------------------------------------------------------------------\n")

# calculate the vector of the document
inferred_vector = model.infer_vector(documents[doc_index].words)

# get the most similar documents
sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))

# get the most similar documents (the limit is set by the user)
for label, index in loc_list:
    
    location = documents[sims[index][0]].tags[0]
    
    # print the title
    print('%s: <%s> (ID:%s)\n' % (label, combo_df.title[location], combo_df.paper_id[location]))
    
    # print the text
    print('Text:',' '.join(documents[sims[index][0]].words))
    
    print("-----------------------------------------------------------------------------\n")
# Out:
# Please Enter the Number of Similar Papers to Find:
# 5
# Please Enter a Paper ID:
# 63fbcac09bf2a0133b41cb99e93dd2ce3aeeab05
#
#
# Searching for similar documents to <Live-attenuated bivalent measles virus-derived vaccines targeting Middle East respiratory syndrome coronavirus induce robust and multifunctional T cell responses against both viruses in an appropriate mouse model> (ID:63fbcac09bf2a0133b41cb99e93dd2ce3aeeab05)
# -----------------------------------------------------------------------------
#
# Most Similar 1: <The Adjuvanticity of an O. volvulus-Derived rOv-ASP-1 Protein in Mice Using Sequential Vaccinations and in Non-Human Primates> (ID:eff3310317521aed7abe06ef1fa9963ca9d6caf3)
#
# Text: adjuvant potentiate antigen specific protective immune response key element promote vaccine effectiveness previously report onchocerca volvulus recombinant protein rov asp-1 induce activation maturation naïve human dcs innate adjuvant promote balance th1 th2 response bystander vaccine antigen mouse vaccine antigen promote th1-biased response base pronounce induction th1-associated igg2a igg2b antibody response upregulated production th1 cytokine include il-2 ifn γ tnf α il-6 protein rov asp-1 adjuvant induce anti self antibody important verify host response self affect adjuvanticity rov asp-1 subsequent vaccination different vaccine antigen study establish rov asp-1 adjuvanticity mouse course sequential vaccination vaccine model system receptor bind domain rbd sars cov spike protein commercial influenza virus hemagglutinin ha vaccine comprise virus strain adjuvanticity rov asp-1 retain efficacy similar obtain vaccination high level anti rov asp-1 antibody present sera mouse administration second vaccine demonstrate utility adjuvant human use immunize non human primate nhps rbd plus rov asp-1 show rov asp-1 induce high titre functional protective anti rbd antibody response nhps notably rov asp-1 adjuvant induce high titer antibody self nhps present study provide sound scientific foundation future strategy development novel protein adjuvant
# -----------------------------------------------------------------------------
#
# Most Similar 2: <Avian reovirus sigma C enhances the mucosal and systemic immune responses elicited by antigen-conjugated lactic acid bacteria> (ID:0ea02653a85f4ad7fd8a9e0d7d80bf8e3be885c5)
#
# Text: abstract mucosal surface common site pathogen colonization entry effective mucosal immunity vaccination provide protection primary infection site aim develop new vaccination strategy elicit mucosal immune response new strain enterococcus faecium non pathogenic lactic acid bacteria lab strong cell adhesion ability identify vaccine vector deliver model antigen specifically sigma σ c protein avian reovirus arv functional homolog mammalian reovirus σ1 protein responsible m cell targeting administer subfragment spike protein infectious bronchitis virus ibv effect immunization route immune response assess deliver antigen lab strain intranasal immunization induce strong humoral response intragastic ig immunization immunization produce antigen specific iga systemically lung high iga titer induce lab arv σc protein attach serum mouse immunize lab display divalent antigen strong immune reactivity arv σc protein compare ibv s1 result indicate arv σc protein deliver lab route elicit strong mucosal immunity needle free delivery approach convenient cost effective method vaccine administration especially respiratory infection economic animal furthermore arv σc strong immunogen arv able serve immunoenhancer vaccine especially avian vaccine
# -----------------------------------------------------------------------------
#
# Most Similar 3: <Priming T-cell responses with recombinant measles vaccine vector in a heterologous prime-boost setting in non-human primates> (ID:10a704781b2698846e04cb8eed622851f49e4315)
#
# Text: abstract licensed live attenuate virus vaccine capable express transgene pathogen potential reduce number childhood immunization elicit robust immunity multiple pathogen simultaneously recombinant attenuated measle virus rmv derive edmonston zagreb vaccine strain engineer express simian immunodeficiency virus siv gag protein purpose evaluate immunogenicity rmv vaccine vector rhesus macaque rmv gag immunization elicit robust measle specific humoral cellular response fail elicit transgene gag)-specific immune response follow aerosol intratracheal intramuscular delivery administer prime vaccine heterologous boost recombinant adenovirus serotype 5 express transgene rmv gag significantly enhance gag specific t lymphocyte response follow rad5 immunization gag specific humoral response enhance transgene vector cellular response priming rmv transgene highly effective suboptimal dose rad5 boost datum demonstrate feasibility rmv prime component heterologous prime boost vaccine regimen pathogen require strong cellular response
# -----------------------------------------------------------------------------
#
# Most Similar 4: <Recombinant hemagglutinin produced from Chinese Hamster Ovary (CHO) stable cell clones and a PELC/CpG combination adjuvant for H7N9 subunit vaccine development> (ID:abb3823535316f016054cdbfdcf5e47680e75d0d)
#
# Text: abstract novel h7n9 avian influenza virus cause human infection china 2013 isolate fifth wave infection emerge highly pathogenic avian influenza virus recombinant hemagglutinin protein h7n9 virus rapidly efficiently produce low level biocontainment facility study recombinant h7 antigen obtain engineer stable clone chinese hamster ovary cho cell subsequent large scale production stable cho cell clone adapt grow serum free suspension culture improve immunogenicity recombinant h7 antigen evaluate use novel combination adjuvant pelc cpg pelc cpg augment anti h7n9 immune response mouse compare effect adjuvant alum addavax mf59-like toll like receptor ligand r848 cpg poly c pelc cpg combination adjuvant cho cell express rh7 antigen contain terminally sialylated complex type n glycan able induce high titer neutralize antibody sera confer protection follow live virus challenge datum indicate cho cell express recombinant h7 antigen pelc cpg combination adjuvant h7n9 subunit vaccine development
# -----------------------------------------------------------------------------
#
# Most Similar 5: <Novel chimeric virus-like particles vaccine displaying MERS-CoV receptor-binding domain induce specific humoral and cellular immune response in mice> (ID:0ea86045c0a8a03ce313440eb1e887f26a85cae3)
#
# Text: abstract middle east respiratory syndrome coronavirus mers cov continue spread emergence 2012 mortality rate 35.6 potential pandemic threat prophylactic therapy urgently need address public health problem report efficacy vaccine consist chimeric virus like particle vlp express receptor binding domain rbd mers cov study fusion canine parvovirus cpv vp2 structural protein gene rbd mers cov self assemble chimeric spherical vlp svlp svlp retain certain parvovirus characteristic ability agglutinate pig erythrocyte structural morphology similar cpv virion immunization svlp induce rbd specific humoral cellular immune response mouse svlp specific antisera animal able prevent pseudotyped mers cov entry susceptible cell neutralize antibody titer reach 1 320 ifn γ il-4 il-2 secreting cell induce rbd detect splenocyte vaccinated mouse elispot furthermore mouse inoculate svlp adjuvanted svlp vaccine elicited t helper 1 th1 t helper 2 th2 cell mediate immunity study demonstrate svlp display rbd mers cov promise prophylactic candidate mers cov potential outbreak situation
# -----------------------------------------------------------------------------

# %% [markdown]
# # Topic Analysis (LDiA)

# %% [markdown]
# 11 April 2020

# %%
# load the dependencies
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD

from tqdm import tqdm_notebook as tqdm

# %%
# load the english language
nlp = spacy.load('en_core_web_md')

# %% [markdown]
# tokenize

# %%
look_at = "abstract"
combo_df["abstract_nlp"] = ""

# create tokens for every doc
for i in tqdm(combo_df.index):
    text = combo_df.iloc[i, combo_df.columns.get_loc(look_at)]
    text = text.lower()
    text = nlp(text)
    text2 = [token for token in text if token.is_stop == False]
    text2 = [token for token in text2 if token.is_punct == False]
    text3 = []
    for token in text2:
        text3.append(token.lemma_)
    combo_df.iloc[i, combo_df.columns.get_loc("abstract_nlp")] = str(text3)
# Out:
# C:\Users\blitz\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=27690.0), HTML(value='')))

# %%
combo_df
# Out:
#                                        paper_id  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      0139ea4ca580af99b602c6435368e7fdbefacb03
# 4      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# ...                                         ...
# 27685  ff3db609dbf2669d8d528279ef32280c2646ba85
# 27686  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 27687  ff6d57f2aad99be129432058665b361dc18747e8
# 27688  ff83907653a4c4500e8c509ca28169e924742b40
# 27689  ffe718db1820f27bf274e3fc519ab78e450de288
#
#                                                     body  \
# 0      VP3, and VP0 (which is further processed to VP...
# 1      The 2019-nCoV epidemic has spread across China...
# 2      Infectious bronchitis (IB), which is caused by...
# 3      Nipah is an infectious negative-sense single-s...
# 4      In December 2019, a cluster of patients with p...
# ...                                                  ...
# 27685  Over the past few decades, the world has witne...
# 27686  Regardless of geographic location, respiratory...
# 27687  Experiments were designed to test whether subs...
# 27688  can function in an autonomous fashion, relocat...
# 27689  Tick-borne encephalitis virus (TBEV) is a huma...
#
#                                             sha  \
# 0      0015023cc06b5362d332b3baf348d11567ca2fbb
# 1      004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2      00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3      0139ea4ca580af99b602c6435368e7fdbefacb03
# 4      013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# ...                                         ...
# 27685  ff3db609dbf2669d8d528279ef32280c2646ba85
# 27686  ff5a79ed22ea416e6d89caad1cf0d83dbc741a4b
# 27687  ff6d57f2aad99be129432058665b361dc18747e8
# 27688  ff83907653a4c4500e8c509ca28169e924742b40
# 27689  ffe718db1820f27bf274e3fc519ab78e450de288
#
#                                                    title  \
# 0      The RNA pseudoknots in foot-and-mouth disease ...
# 1      Healthcare-resource-adjusted vulnerabilities t...
# 2      Real-time, MinION-based, amplicon sequencing f...
# 3      A Combined Evidence Approach to Prioritize Nip...
# 4      Assessing spread risk of Wuhan novel coronavir...
# ...                                                  ...
# 27685  More than efficacy revealed by single-cell ana...
# 27686          Understanding Human Coronavirus HCoV-NL63
# 27687  Macrophages genetically resistant to mouse hep...
# 27688  Identification of a subdomain of CENP-B that i...
# 27689  Replication enhancer elements within the open ...
#
#                                doi       pmcid   pubmed_id      license  \
# 0        10.1101/2020.01.10.901801         NaN         NaN      biorxiv
# 1      10.1101/2020.02.11.20022111         NaN         NaN      medrvix
# 2                   10.1101/634600         NaN         NaN      biorxiv
# 3        10.1101/2020.03.12.977918         NaN         NaN      biorxiv
# 4      10.1101/2020.02.04.20020479         NaN         NaN      medrvix
# ...                            ...         ...         ...          ...
# 27685       10.1126/sciadv.aax4761  PMC6821460  31692968.0     cc-by-nc
# 27686  10.2174/1874357901004010076  PMC2918871  20700397.0     cc-by-nc
# 27687                          NaN  PMC2190139    175127.0  cc-by-nc-sa
# 27688                          NaN  PMC2289363   1740467.0  cc-by-nc-sa
# 27689           10.1093/nar/gkr237  PMC3303483  21622960.0     cc-by-nc
#
#                                                 abstract publish_time  \
# 0      The positive stranded RNA genomes of picornavi...   2020-01-11
# 1      We integrate the human movement and healthcare...   2020-02-12
# 2      Infectious bronchitis (IB) causes significant ...   2019-05-10
# 3      AbstractBackgroundNipah Virus (NiV) came into ...   2020-03-12
# 4      Background: A novel coronavirus (2019-nCoV) em...   2020-02-05
# ...                                                  ...          ...
# 27685  Because many aspects of viral infection dynami...  2019 Oct 30
# 27686  Even though coronavirus infection of humans is...  2010 May 25
# 27687  Genetic resistance to mouse hepatitis, which r...   1976 Mar 1
# 27688  We have combined in vivo and in vitro approach...   1992 Mar 1
# 27689  We provide experimental evidence of a replicat...  2011 Sep 27
#
#                                                  authors            journal  \
# 0      Ward, J. C. J.; Lasecka-Dykes, L.; Neil, C.; A...                NaN
# 1      Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...                NaN
# 2      Butt, S. L.; Erwood, E. C.; Zhang, J.; Sellers...                NaN
# 3      Nishi Kumari; Ayush Upadhyay; Kishan Kalia; Ra...                NaN
# 4      Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...                NaN
# ...                                                  ...                ...
# 27685  Liu, Wu; Caglar, Mehmet U.; Mao, Zhangming; Wo...            Sci Adv
# 27686           Abdul-Rasool, Sahar; Fielding, Burtram C       Open Virol J
# 27687                                                NaN          J Exp Med
# 27688                                                NaN        J Cell Biol
# 27689  Tuplin, A.; Evans, D. J.; Buckley, A.; Jones, ...  Nucleic Acids Res
#
#        Microsoft Academic Paper ID WHO #Covidence  has_full_text  \
# 0                              NaN            NaN           True
# 1                              NaN            NaN           True
# 2                              NaN            NaN           True
# 3                              NaN            NaN           True
# 4                              NaN            NaN           True
# ...                            ...            ...            ...
# 27685                          NaN            NaN           True
# 27686                          NaN            NaN           True
# 27687                          NaN            NaN           True
# 27688                          NaN            NaN           True
# 27689                          NaN            NaN           True
#
#            full_text_file                                       abstract_nlp
# 0         biorxiv_medrxiv  ['positive', 'strand', 'rna', 'genome', 'picor...
# 1         biorxiv_medrxiv  ['integrate', 'human', 'movement', 'healthcare...
# 2         biorxiv_medrxiv  ['infectious', 'bronchitis', 'ib', 'cause', 's...
# 3         biorxiv_medrxiv  ['abstractbackgroundnipah', 'virus', 'niv', 'c...
# 4         biorxiv_medrxiv  ['background', 'novel', 'coronavirus', '2019-n...
# ...                   ...                                                ...
# 27685  noncomm_use_subset  ['aspect', 'viral', 'infection', 'dynamic', 'i...
# 27686  noncomm_use_subset  ['coronavirus', 'infection', 'human', 'normall...
# 27687  noncomm_use_subset  ['genetic', 'resistance', 'mouse', 'hepatitis'...
# 27688  noncomm_use_subset  ['combine', 'vivo', 'vitro', 'approach', 'inve...
# 27689  noncomm_use_subset  ['provide', 'experimental', 'evidence', 'repli...
#
# [27690 rows x 17 columns]

# %%
# create and fit the count vectorizer
vectorizer = CountVectorizer()
df_vectorized = vectorizer.fit_transform(combo_df["abstract_nlp"])

# %%
# create a ldia model and fit it to the count vector data
ldia = LatentDirichletAllocation(n_components=10, max_iter=10,verbose=True)
ldia_model = ldia.fit_transform(df_vectorized)

# create a nmf model and fit it to the count vector data
nmf = NMF(n_components=10)
nmf_model = nmf.fit_transform(df_vectorized) 

# create a lsa model and fit it to the count vector data
lsa = TruncatedSVD(n_components=10)
lsa_model = lsa.fit_transform(df_vectorized)
# Out:
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %%
def selected_topics(model, vectorizer, top_n=10):
    for i, topic in enumerate(model.components_):
        print("Topic %d:" % (i))
        print([(vectorizer.get_feature_names()[x], topic[x]) for x in topic.argsort()[:-top_n - 1:-1]])
        print("-------------------------------------------------------------------------")

def selected_topics_names(model, vectorizer, top_n=10):
    for i, topic in enumerate(model.components_):
        print("Topic %d:" % (i))       
        print([(vectorizer.get_feature_names()[x]) for x in topic.argsort()[:-top_n - 1:-1]])
        print("-------------------------------------------------------------------------")

# %%
print("LDiA Model:")
selected_topics(ldia, vectorizer)
print("#########################################################################")

print("NMF Model:")
selected_topics(nmf, vectorizer)
print("#########################################################################")

print("LSA Model:")
selected_topics(lsa, vectorizer)
print("#########################################################################")
# Out:
# LDiA Model:
# Topic 0:
# [('infection', 6083.323410144752), ('cell', 4783.677664086467), ('disease', 4453.770217147687), ('immune', 2708.0975777045514), ('response', 2606.03546950463), ('mouse', 2541.743159013706), ('lung', 2420.5627408501846), ('il', 2305.423439215534), ('treatment', 2033.7303812849852), ('cat', 2002.1828067600495)]
# -------------------------------------------------------------------------
# Topic 1:
# [('cell', 13766.032661883424), ('virus', 8584.415543410843), ('protein', 8553.289941976767), ('viral', 5321.67419547165), ('infection', 4703.5285885616095), ('rna', 3970.993621451902), ('replication', 3717.689787475229), ('activity', 3663.1464973125057), ('expression', 3538.285704510566), ('antiviral', 2764.4675687582626)]
# -------------------------------------------------------------------------
# Topic 2:
# [('antibody', 5452.150326902909), ('vaccine', 5080.947295208966), ('virus', 4901.84262045198), ('strain', 3795.697560807346), ('cell', 3683.016057646475), ('protein', 2808.893960701989), ('pedv', 2311.978155630324), ('response', 2279.663167183034), ('gene', 2144.9315388621276), ('pig', 2116.5001841097046)]
# -------------------------------------------------------------------------
# Topic 3:
# [('health', 3889.3765560584643), ('model', 2926.9879768924675), ('disease', 2532.7446863431737), ('study', 2316.182373412619), ('result', 1858.7763076330525), ('datum', 1775.4232108859885), ('care', 1682.540247958297), ('outbreak', 1665.5431195221684), ('public', 1646.4678565530226), ('epidemic', 1641.6413332721502)]
# -------------------------------------------------------------------------
# Topic 4:
# [('disease', 6221.499872551859), ('influenza', 6076.784241714903), ('virus', 4501.626309887225), ('health', 4490.309876726653), ('human', 3275.3516160051195), ('infection', 2482.6894709069593), ('infectious', 2342.340148920262), ('vaccine', 2250.3472918480534), ('review', 2139.2195530525387), ('pandemic', 1979.7929519226814)]
# -------------------------------------------------------------------------
# Topic 5:
# [('protein', 3827.843142749444), ('sequence', 3296.826753372622), ('virus', 2792.8079915317394), ('gene', 2693.912130722822), ('base', 2527.7049397347305), ('structure', 2359.86033234855), ('genome', 2283.9708565721476), ('rna', 2226.5036729378235), ('analysis', 2139.9824837182086), ('study', 1850.2580048319937)]
# -------------------------------------------------------------------------
# Topic 6:
# [('patient', 9423.425538359661), ('case', 5010.244221247966), ('study', 3345.0320088447734), ('infection', 3335.273611253604), ('day', 2882.3123767524053), ('group', 2823.2365395014563), ('high', 2754.687166393701), ('respiratory', 2453.2396779299384), ('95', 2425.3858664908817), ('result', 2260.0454063161956)]
# -------------------------------------------------------------------------
# Topic 7:
# [('cov', 5922.01671042252), ('sars', 5577.568993284427), ('virus', 4635.236967555683), ('human', 2982.9725046545163), ('coronavirus', 2834.574629565292), ('respiratory', 2220.360466659191), ('bat', 2138.697034228395), ('mers', 2035.1767880639984), ('viral', 1776.2962590776006), ('syndrome', 1571.069609699674)]
# -------------------------------------------------------------------------
# Topic 8:
# [('de', 4338.2348680709), ('la', 2378.0977736325494), ('en', 1601.099909427762), ('et', 1051.8063246747904), ('les', 896.8971004362455), ('el', 865.0999825898858), ('des', 860.8312742469428), ('los', 754.3547524193596), ('un', 672.891985218524), ('las', 621.099994661987)]
# -------------------------------------------------------------------------
# Topic 9:
# [('virus', 8782.759751460897), ('respiratory', 6024.579558104177), ('sample', 5353.189654592335), ('pcr', 4929.5955302539915), ('infection', 4626.905755628794), ('detect', 4010.666916397693), ('assay', 3574.6713016288218), ('detection', 3369.7795283592263), ('test', 3213.301902888531), ('viral', 3208.586964861025)]
# -------------------------------------------------------------------------
# #########################################################################
# NMF Model:
# Topic 0:
# [('kim', 17.223977079112615), ('lee', 10.681780856762645), ('young', 8.445184068404625), ('park', 7.134254390236363), ('asthma', 5.206608786644553), ('jung', 4.697423629236884), ('allergic', 4.60523289648197), ('hee', 4.45380840537255), ('child', 4.438946716680075), ('hyun', 4.10585462370282)]
# -------------------------------------------------------------------------
# Topic 1:
# [('cell', 20.620365985680177), ('expression', 2.440192806122283), ('response', 2.364925831492636), ('induce', 2.2509790734369957), ('mouse', 2.159047462053127), ('immune', 1.8122110256917527), ('il', 1.5015162705636977), ('effect', 1.489692018416874), ('ifn', 1.489622114406985), ('result', 1.4406589288457539)]
# -------------------------------------------------------------------------
# Topic 2:
# [('patient', 13.987844349600183), ('care', 4.501355071352098), ('intensive', 2.4724092757966436), ('outcome', 2.328211896842093), ('icu', 2.2022915046058498), ('study', 2.1938453273698624), ('unit', 2.1371356110335955), ('acute', 2.015155212350994), ('hospital', 1.9918598617222265), ('severe', 1.670555214561837)]
# -------------------------------------------------------------------------
# Topic 3:
# [('virus', 18.442345589634055), ('influenza', 3.0077329166875653), ('viral', 2.614937541601411), ('human', 2.2117911982415484), ('rna', 1.5337564482901245), ('host', 1.2573512206513162), ('respiratory', 1.1495575046561695), ('replication', 0.8428599790074912), ('vaccine', 0.7919301996948452), ('genome', 0.783663927696198)]
# -------------------------------------------------------------------------
# Topic 4:
# [('de', 15.435140324183859), ('la', 8.343254819361048), ('en', 5.969661130285712), ('el', 3.528986786193544), ('los', 2.9301410023593086), ('las', 2.548166472984509), ('et', 2.5072330201013444), ('les', 2.4022605236082026), ('des', 2.3227152687596013), ('un', 2.0192754354974296)]
# -------------------------------------------------------------------------
# Topic 5:
# [('disease', 9.839675228296285), ('health', 7.450964969668832), ('infectious', 3.0964671318370396), ('public', 2.864099941425583), ('model', 2.8146496794988853), ('system', 2.7075932497129833), ('outbreak', 2.5451660320108735), ('study', 2.322742396336565), ('datum', 2.277885197879271), ('human', 2.265446598693213)]
# -------------------------------------------------------------------------
# Topic 6:
# [('protein', 14.49331402776312), ('rna', 3.459130182302594), ('gene', 2.9722292810335453), ('viral', 2.783948174348745), ('sequence', 2.4110851511180225), ('expression', 1.6270266496261039), ('membrane', 1.6213663961308573), ('study', 1.6037948806742262), ('analysis', 1.5522623147224823), ('domain', 1.5246326586432801)]
# -------------------------------------------------------------------------
# Topic 7:
# [('cov', 11.189995432884356), ('sars', 9.848472521773258), ('mers', 5.480903602293665), ('coronavirus', 2.927858623500099), ('respiratory', 2.2102458485421344), ('syndrome', 2.209629035684559), ('human', 2.09898572106556), ('case', 1.5991831263434966), ('severe', 1.5477626655877585), ('acute', 1.2267528567275838)]
# -------------------------------------------------------------------------
# Topic 8:
# [('sample', 4.101148040622439), ('study', 3.936085618885851), ('pcr', 3.6588646652690504), ('result', 3.3392838018530564), ('group', 2.954556154282261), ('respiratory', 2.934250236886132), ('assay', 2.8514605358292204), ('method', 2.7371850449859747), ('test', 2.6124452955452107), ('detect', 2.595458173442867)]
# -------------------------------------------------------------------------
# Topic 9:
# [('infection', 16.28042656488263), ('viral', 4.623864515382329), ('respiratory', 3.2586600042788714), ('response', 1.5197859823043491), ('child', 1.3208970700900529), ('cause', 1.3070472539956803), ('disease', 1.1461243891285466), ('immune', 1.1038875001614556), ('associate', 1.011772446200295), ('acute', 0.935744199532943)]
# -------------------------------------------------------------------------
# #########################################################################
# LSA Model:
# Topic 0:
# [('kim', 0.49587482610991157), ('lee', 0.308083790563001), ('young', 0.24602091695560466), ('park', 0.20593837192806086), ('patient', 0.17522985219963333), ('asthma', 0.15294415345864285), ('child', 0.1415920743776806), ('jung', 0.1352087906877134), ('allergic', 0.13318441813535156), ('hee', 0.12819535309644717)]
# -------------------------------------------------------------------------
# Topic 1:
# [('kim', 0.22592951606788353), ('lee', 0.1390971373009507), ('young', 0.10111870213534442), ('park', 0.0924673612693221), ('jung', 0.061674739314507364), ('hee', 0.05848045169380682), ('allergic', 0.058293078094930735), ('asthma', 0.0578341129560553), ('hyun', 0.05391166640522813), ('soo', 0.04477409582807084)]
# -------------------------------------------------------------------------
# Topic 2:
# [('patient', 0.5037004437380638), ('care', 0.17291067509548266), ('respiratory', 0.11581229054093528), ('case', 0.11426521530629184), ('de', 0.11387367336354653), ('disease', 0.10721312066863015), ('health', 0.09887116186183299), ('study', 0.09823398424189564), ('hospital', 0.0981278807709415), ('intensive', 0.08313561595337053)]
# -------------------------------------------------------------------------
# Topic 3:
# [('cell', 0.46137680601288494), ('protein', 0.22185990590157684), ('patient', 0.1547549755397599), ('sars', 0.10160049933373011), ('expression', 0.09475218700708612), ('response', 0.08822186810746696), ('cov', 0.08357282602385906), ('care', 0.07556859432261599), ('study', 0.07556685116401944), ('induce', 0.061174065428447874)]
# -------------------------------------------------------------------------
# Topic 4:
# [('de', 0.6072422194893489), ('la', 0.31982320698712113), ('cell', 0.3185579722047453), ('en', 0.22793623096292162), ('patient', 0.16925812334605472), ('el', 0.13679638434134356), ('los', 0.1121816076715052), ('las', 0.09850105744248579), ('et', 0.09471013426168064), ('les', 0.0911232754895088)]
# -------------------------------------------------------------------------
# Topic 5:
# [('patient', 0.4240563152787904), ('virus', 0.2772405783601529), ('cell', 0.1719003583232373), ('infection', 0.10557729113645464), ('respiratory', 0.09590005860409234), ('care', 0.09488010755183035), ('intensive', 0.07447318228158818), ('viral', 0.0722222650179315), ('icu', 0.06750417091007), ('unit', 0.059290986066142685)]
# -------------------------------------------------------------------------
# Topic 6:
# [('protein', 0.5207619838915364), ('cov', 0.2911543663903357), ('sars', 0.2883179912152017), ('patient', 0.1749543519686623), ('rna', 0.16352421059844838), ('sequence', 0.12736344634861854), ('mers', 0.10549557480030126), ('coronavirus', 0.09982586908278933), ('virus', 0.08946327096860274), ('genome', 0.07405545368528402)]
# -------------------------------------------------------------------------
# Topic 7:
# [('virus', 0.19787509427125413), ('care', 0.13444744135026732), ('health', 0.12638098621664728), ('patient', 0.1195544116353734), ('protein', 0.09340325669076344), ('rna', 0.08493015365791141), ('system', 0.0799334191795668), ('disease', 0.07631403333638263), ('study', 0.0755155080608338), ('intensive', 0.07054801743718558)]
# -------------------------------------------------------------------------
# Topic 8:
# [('virus', 0.277909309654929), ('health', 0.24901239234402522), ('cov', 0.2386852722786462), ('sars', 0.23583918079878732), ('disease', 0.1945959981990065), ('cell', 0.18111924214319727), ('human', 0.15060342378048303), ('mers', 0.11556777980934105), ('care', 0.10345990017907326), ('influenza', 0.09818640465801413)]
# -------------------------------------------------------------------------
# Topic 9:
# [('infection', 0.4685994221906778), ('viral', 0.29441461128945173), ('protein', 0.2442715679202343), ('disease', 0.1603486539180696), ('host', 0.1363621877341411), ('response', 0.08858076323561308), ('rna', 0.08422932755152553), ('replication', 0.06835232732027188), ('immune', 0.05879604727185843), ('role', 0.05862703010497408)]
# -------------------------------------------------------------------------
# #########################################################################

# %%
print("LDiA Model:")
selected_topics_names(ldia, vectorizer)
print("#########################################################################")

print("NMF Model:")
selected_topics_names(nmf, vectorizer)
print("#########################################################################")

print("LSA Model:")
selected_topics_names(lsa, vectorizer)
print("#########################################################################")
# Out:
# LDiA Model:
# Topic 0:
# ['infection', 'cell', 'disease', 'immune', 'response', 'mouse', 'lung', 'il', 'treatment', 'cat']
# -------------------------------------------------------------------------
# Topic 1:
# ['cell', 'virus', 'protein', 'viral', 'infection', 'rna', 'replication', 'activity', 'expression', 'antiviral']
# -------------------------------------------------------------------------
# Topic 2:
# ['antibody', 'vaccine', 'virus', 'strain', 'cell', 'protein', 'pedv', 'response', 'gene', 'pig']
# -------------------------------------------------------------------------
# Topic 3:
# ['health', 'model', 'disease', 'study', 'result', 'datum', 'care', 'outbreak', 'public', 'epidemic']
# -------------------------------------------------------------------------
# Topic 4:
# ['disease', 'influenza', 'virus', 'health', 'human', 'infection', 'infectious', 'vaccine', 'review', 'pandemic']
# -------------------------------------------------------------------------
# Topic 5:
# ['protein', 'sequence', 'virus', 'gene', 'base', 'structure', 'genome', 'rna', 'analysis', 'study']
# -------------------------------------------------------------------------
# Topic 6:
# ['patient', 'case', 'study', 'infection', 'day', 'group', 'high', 'respiratory', '95', 'result']
# -------------------------------------------------------------------------
# Topic 7:
# ['cov', 'sars', 'virus', 'human', 'coronavirus', 'respiratory', 'bat', 'mers', 'viral', 'syndrome']
# -------------------------------------------------------------------------
# Topic 8:
# ['de', 'la', 'en', 'et', 'les', 'el', 'des', 'los', 'un', 'las']
# -------------------------------------------------------------------------
# Topic 9:
# ['virus', 'respiratory', 'sample', 'pcr', 'infection', 'detect', 'assay', 'detection', 'test', 'viral']
# -------------------------------------------------------------------------
# #########################################################################
# NMF Model:
# Topic 0:
# ['kim', 'lee', 'young', 'park', 'asthma', 'jung', 'allergic', 'hee', 'child', 'hyun']
# -------------------------------------------------------------------------
# Topic 1:
# ['cell', 'expression', 'response', 'induce', 'mouse', 'immune', 'il', 'effect', 'ifn', 'result']
# -------------------------------------------------------------------------
# Topic 2:
# ['patient', 'care', 'intensive', 'outcome', 'icu', 'study', 'unit', 'acute', 'hospital', 'severe']
# -------------------------------------------------------------------------
# Topic 3:
# ['virus', 'influenza', 'viral', 'human', 'rna', 'host', 'respiratory', 'replication', 'vaccine', 'genome']
# -------------------------------------------------------------------------
# Topic 4:
# ['de', 'la', 'en', 'el', 'los', 'las', 'et', 'les', 'des', 'un']
# -------------------------------------------------------------------------
# Topic 5:
# ['disease', 'health', 'infectious', 'public', 'model', 'system', 'outbreak', 'study', 'datum', 'human']
# -------------------------------------------------------------------------
# Topic 6:
# ['protein', 'rna', 'gene', 'viral', 'sequence', 'expression', 'membrane', 'study', 'analysis', 'domain']
# -------------------------------------------------------------------------
# Topic 7:
# ['cov', 'sars', 'mers', 'coronavirus', 'respiratory', 'syndrome', 'human', 'case', 'severe', 'acute']
# -------------------------------------------------------------------------
# Topic 8:
# ['sample', 'study', 'pcr', 'result', 'group', 'respiratory', 'assay', 'method', 'test', 'detect']
# -------------------------------------------------------------------------
# Topic 9:
# ['infection', 'viral', 'respiratory', 'response', 'child', 'cause', 'disease', 'immune', 'associate', 'acute']
# -------------------------------------------------------------------------
# #########################################################################
# LSA Model:
# Topic 0:
# ['kim', 'lee', 'young', 'park', 'patient', 'asthma', 'child', 'jung', 'allergic', 'hee']
# -------------------------------------------------------------------------
# Topic 1:
# ['kim', 'lee', 'young', 'park', 'jung', 'hee', 'allergic', 'asthma', 'hyun', 'soo']
# -------------------------------------------------------------------------
# Topic 2:
# ['patient', 'care', 'respiratory', 'case', 'de', 'disease', 'health', 'study', 'hospital', 'intensive']
# -------------------------------------------------------------------------
# Topic 3:
# ['cell', 'protein', 'patient', 'sars', 'expression', 'response', 'cov', 'care', 'study', 'induce']
# -------------------------------------------------------------------------
# Topic 4:
# ['de', 'la', 'cell', 'en', 'patient', 'el', 'los', 'las', 'et', 'les']
# -------------------------------------------------------------------------
# Topic 5:
# ['patient', 'virus', 'cell', 'infection', 'respiratory', 'care', 'intensive', 'viral', 'icu', 'unit']
# -------------------------------------------------------------------------
# Topic 6:
# ['protein', 'cov', 'sars', 'patient', 'rna', 'sequence', 'mers', 'coronavirus', 'virus', 'genome']
# -------------------------------------------------------------------------
# Topic 7:
# ['virus', 'care', 'health', 'patient', 'protein', 'rna', 'system', 'disease', 'study', 'intensive']
# -------------------------------------------------------------------------
# Topic 8:
# ['virus', 'health', 'cov', 'sars', 'disease', 'cell', 'human', 'mers', 'care', 'influenza']
# -------------------------------------------------------------------------
# Topic 9:
# ['infection', 'viral', 'protein', 'disease', 'host', 'response', 'rna', 'replication', 'immune', 'role']
# -------------------------------------------------------------------------
# #########################################################################

# %% [markdown]
# # Clustering

# %% [markdown]
# April 2020

# %%
# from sklearn.cluster import KMeans
# from sklearn.decomposition import PCA

# kmeans_model = KMeans(n_clusters=25, max_iter=100) 

# X = kmeans_model.fit(model.docvecs.vectors_docs)

# labels=kmeans_model.labels_.tolist()

# l = kmeans_model.fit_predict(model.docvecs.vectors_docs)

# pca = PCA(n_components=2).fit(model.docvecs.vectors_docs)

# datapoint = pca.transform(model.docvecs.vectors_docs)

# import matplotlib.pyplot as plt

# label1 = ['#FFFF00', '#008000', '#0000FF', '#800080']
# color = [label1[i] for i in labels]

# plt.scatter(datapoint[:, 0], datapoint[:, 1], c=color)

# centroids = kmeans_model.cluster_centers_

# centroidpoint = pca.transform(centroids)

# plt.scatter(centroidpoint[:, 0], centroidpoint[:, 1], marker='^', s=150, c='#000000')

# plt.show()
